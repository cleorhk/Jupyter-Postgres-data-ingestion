# %%
import pandas as pd
pd. __version__
# Out:
# '2.2.2'

# %%
import pandas as pd
df=pd.read_csv('green_tripdata_2019-09.csv', nrows=10)
df
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1         2  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2         2  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3         2  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4         2  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# 5         2  2019-09-01 00:55:37   2019-09-01 01:17:02                  N
# 6         2  2019-09-01 00:28:55   2019-09-01 00:52:09                  N
# 7         1  2019-09-01 00:03:13   2019-09-01 00:03:32                  N
# 8         1  2019-09-01 00:15:28   2019-09-01 00:43:22                  N
# 9         2  2019-09-01 00:29:16   2019-09-01 00:30:15                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            65           189                5           2.00
# ...

# %%
df.lpep_pickup_datetime=pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime=pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df_iter=pd.read_csv('green_tripdata_2019-09.csv', iterator=True, chunksize=10000)
df=next(df_iter)

# %%
df.head(n=0).to_sql(name= 'green_taxi_data', if_exists='replace')

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import pandas as pd
from sqlalchemy import create_engine

# Define the connection string
connection_string = 'postgresql://postgres:cleo2030@localhost/nytaxi'

# Create an engine
engine = create_engine(connection_string)

# Read the CSV file into a DataFrame
df = pd.read_csv('green_tripdata_2019-09.csv', low_memory=False)

# Load the DataFrame into the PostgreSQL database
df.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace', index=False)
# Out:
# 0

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data'))
# Out:
# CREATE TABLE "green_taxi_data" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL
# )

# %%
from time import time

while True:
    try:
        t_start = time()
        df = next(df_iter)

        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

        df.to_sql(name='green_taxi_data', con=engine, if_exists='append', index=False)
        
        t_end = time()
        
        print(f"Inserted a chunk in {t_end - t_start:.2f} seconds")
        
    except StopIteration:
        print("All data inserted.")
        break
# Out:
# Inserted a chunk in 1.22 seconds
# Inserted a chunk in 1.19 seconds
# Inserted a chunk in 1.64 seconds
# Inserted a chunk in 1.11 seconds
# Inserted a chunk in 1.07 seconds
# Inserted a chunk in 1.14 seconds
# Inserted a chunk in 1.19 seconds
# Inserted a chunk in 1.14 seconds
# Inserted a chunk in 1.13 seconds
# Inserted a chunk in 1.08 seconds
# Inserted a chunk in 1.26 seconds
# Inserted a chunk in 1.23 seconds
# Inserted a chunk in 1.17 seconds
# Inserted a chunk in 1.01 seconds
# Inserted a chunk in 1.15 seconds
# Inserted a chunk in 1.16 seconds
# Inserted a chunk in 1.26 seconds
# Inserted a chunk in 1.30 seconds
# Inserted a chunk in 1.21 seconds
# Inserted a chunk in 1.24 seconds
# Inserted a chunk in 1.27 seconds
# Inserted a chunk in 1.15 seconds
# Inserted a chunk in 1.20 seconds
# Inserted a chunk in 1.30 seconds
# Inserted a chunk in 1.22 seconds
# Inserted a chunk in 1.26 seconds
# Inserted a chunk in 1.32 seconds
# Inserted a chunk in 1.19 seconds
# ...
